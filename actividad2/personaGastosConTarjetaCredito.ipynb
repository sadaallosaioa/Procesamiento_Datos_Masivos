# %%
#Instalamos Java
# !apt-get install openjdk-8-jdk-headless --quiet > /dev/null

# %%
#.Descargamos Spark: para ello tenemos que indicar:
# !wget --quiet https://dlcdn.apache.org/spark/spark-3.4.2/spark-3.4.2-bin-hadoop3.tgz

# %%
#descomprimo Hadoop:
# !tar xf spark-3.4.2-bin-hadoop3.tgz

# %%
#Creamos las variables de entorno de java y Spark. Para ello creamos una nueva nota con lo siguiente:
import os
os.environ["JAVA_HOME"] = "/usr/lib/jvm/java-8-openjdk-amd64"
os.environ["SPARK_HOME"] = "/content/spark-3.4.2-bin-hadoop3"

# %%
#Instalamos findspark para que nos permita importar pyspark de forma sencilla como una librería:
# !pip install --quiet findspark

# %%
#Iniciamos findspark:
import findspark
findspark.init()

# %% [markdown]
# (Subir los archivos implicados en el comando siguiente)

# %%
#Ejecutamos el programa:
# !$SPARK_HOME/bin/spark-submit /content/A2Ej1.py /content/miEntrada.txt /content/Salida
# Out:
# 24/01/12 16:43:12 INFO SparkContext: Running Spark version 3.4.2
# 24/01/12 16:43:12 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# 24/01/12 16:43:12 INFO ResourceUtils: ==============================================================
# 24/01/12 16:43:12 INFO ResourceUtils: No custom resources configured for spark.driver.
# 24/01/12 16:43:12 INFO ResourceUtils: ==============================================================
# 24/01/12 16:43:12 INFO SparkContext: Submitted application: personaGastosConTarjetaCredito
# 24/01/12 16:43:12 INFO ResourceProfile: Default ResourceProfile created, executor resources: Map(cores -> name: cores, amount: 1, script: , vendor: , memory -> name: memory, amount: 1024, script: , vendor: , offHeap -> name: offHeap, amount: 0, script: , vendor: ), task resources: Map(cpus -> name: cpus, amount: 1.0)
# 24/01/12 16:43:12 INFO ResourceProfile: Limiting resource is cpu
# 24/01/12 16:43:12 INFO ResourceProfileManager: Added ResourceProfile id: 0
# 24/01/12 16:43:12 INFO SecurityManager: Changing view acls to: root
# 24/01/12 16:43:12 INFO SecurityManager: Changing modify acls to: root
# 24/01/12 16:43:12 INFO SecurityManager: Changing view acls groups to:
# 24/01/12 16:43:12 INFO SecurityManager: Changing modify acls groups to:
# 24/01/12 16:43:12 INFO SecurityManager: SecurityManager: authentication disabled; ui acls disabled; users with view permissions: root; groups with view permissions: EMPTY; users with modify permissions: root; groups with modify permissions: EMPTY
# 24/01/12 16:43:12 INFO Utils: Successfully started service 'sparkDriver' on port 33331.
# 24/01/12 16:43:12 INFO SparkEnv: Registering MapOutputTracker
# 24/01/12 16:43:12 INFO SparkEnv: Registering BlockManagerMaster
# 24/01/12 16:43:12 INFO BlockManagerMasterEndpoint: Using org.apache.spark.storage.DefaultTopologyMapper for getting topology information
# 24/01/12 16:43:12 INFO BlockManagerMasterEndpoint: BlockManagerMasterEndpoint up
# 24/01/12 16:43:12 INFO SparkEnv: Registering BlockManagerMasterHeartbeat
# 24/01/12 16:43:12 INFO DiskBlockManager: Created local directory at /tmp/blockmgr-386258ab-d4b1-4e91-b1d8-df08e20e8e58
# 24/01/12 16:43:12 INFO MemoryStore: MemoryStore started with capacity 366.3 MiB
# 24/01/12 16:43:13 INFO SparkEnv: Registering OutputCommitCoordinator
# 24/01/12 16:43:13 INFO JettyUtils: Start Jetty 0.0.0.0:4040 for SparkUI
# 24/01/12 16:43:13 INFO Utils: Successfully started service 'SparkUI' on port 4040.
# 24/01/12 16:43:13 INFO Executor: Starting executor ID driver on host 51f90827d3d2
# 24/01/12 16:43:13 INFO Executor: Starting executor with user classpath (userClassPathFirst = false): ''
# 24/01/12 16:43:13 INFO Utils: Successfully started service 'org.apache.spark.network.netty.NettyBlockTransferService' on port 40947.
# 24/01/12 16:43:13 INFO NettyBlockTransferService: Server created on 51f90827d3d2:40947
# 24/01/12 16:43:13 INFO BlockManager: Using org.apache.spark.storage.RandomBlockReplicationPolicy for block replication policy
# 24/01/12 16:43:13 INFO BlockManagerMaster: Registering BlockManager BlockManagerId(driver, 51f90827d3d2, 40947, None)
# 24/01/12 16:43:13 INFO BlockManagerMasterEndpoint: Registering block manager 51f90827d3d2:40947 with 366.3 MiB RAM, BlockManagerId(driver, 51f90827d3d2, 40947, None)
# 24/01/12 16:43:13 INFO BlockManagerMaster: Registered BlockManager BlockManagerId(driver, 51f90827d3d2, 40947, None)
# 24/01/12 16:43:13 INFO BlockManager: Initialized BlockManager: BlockManagerId(driver, 51f90827d3d2, 40947, None)
# 24/01/12 16:43:14 INFO MemoryStore: Block broadcast_0 stored as values in memory (estimated size 358.0 KiB, free 366.0 MiB)
# 24/01/12 16:43:14 INFO MemoryStore: Block broadcast_0_piece0 stored as bytes in memory (estimated size 32.5 KiB, free 365.9 MiB)
# 24/01/12 16:43:14 INFO BlockManagerInfo: Added broadcast_0_piece0 in memory on 51f90827d3d2:40947 (size: 32.5 KiB, free: 366.3 MiB)
# 24/01/12 16:43:14 INFO SparkContext: Created broadcast 0 from textFile at NativeMethodAccessorImpl.java:0
# 24/01/12 16:43:14 INFO FileInputFormat: Total input files to process : 1
# 24/01/12 16:43:14 INFO deprecation: mapred.output.dir is deprecated. Instead, use mapreduce.output.fileoutputformat.outputdir
# 24/01/12 16:43:14 INFO HadoopMapRedCommitProtocol: Using output committer class org.apache.hadoop.mapred.FileOutputCommitter
# 24/01/12 16:43:14 INFO FileOutputCommitter: File Output Committer Algorithm version is 1
# 24/01/12 16:43:14 INFO FileOutputCommitter: FileOutputCommitter skip cleanup _temporary folders under output directory:false, ignore cleanup failures: false
# 24/01/12 16:43:14 INFO SparkContext: Starting job: runJob at SparkHadoopWriter.scala:83
# 24/01/12 16:43:15 INFO DAGScheduler: Registering RDD 3 (reduceByKey at /content/A2Ej1.py:29) as input to shuffle 0
# 24/01/12 16:43:15 INFO DAGScheduler: Got job 0 (runJob at SparkHadoopWriter.scala:83) with 2 output partitions
# 24/01/12 16:43:15 INFO DAGScheduler: Final stage: ResultStage 1 (runJob at SparkHadoopWriter.scala:83)
# 24/01/12 16:43:15 INFO DAGScheduler: Parents of final stage: List(ShuffleMapStage 0)
# 24/01/12 16:43:15 INFO DAGScheduler: Missing parents: List(ShuffleMapStage 0)
# 24/01/12 16:43:15 INFO DAGScheduler: Submitting ShuffleMapStage 0 (PairwiseRDD[3] at reduceByKey at /content/A2Ej1.py:29), which has no missing parents
# 24/01/12 16:43:15 INFO MemoryStore: Block broadcast_1 stored as values in memory (estimated size 12.1 KiB, free 365.9 MiB)
# 24/01/12 16:43:15 INFO MemoryStore: Block broadcast_1_piece0 stored as bytes in memory (estimated size 7.5 KiB, free 365.9 MiB)
# 24/01/12 16:43:15 INFO BlockManagerInfo: Added broadcast_1_piece0 in memory on 51f90827d3d2:40947 (size: 7.5 KiB, free: 366.3 MiB)
# 24/01/12 16:43:15 INFO SparkContext: Created broadcast 1 from broadcast at DAGScheduler.scala:1535
# 24/01/12 16:43:15 INFO DAGScheduler: Submitting 2 missing tasks from ShuffleMapStage 0 (PairwiseRDD[3] at reduceByKey at /content/A2Ej1.py:29) (first 15 tasks are for partitions Vector(0, 1))
# 24/01/12 16:43:15 INFO TaskSchedulerImpl: Adding task set 0.0 with 2 tasks resource profile 0
# 24/01/12 16:43:15 INFO TaskSetManager: Starting task 0.0 in stage 0.0 (TID 0) (51f90827d3d2, executor driver, partition 0, PROCESS_LOCAL, 7395 bytes)
# 24/01/12 16:43:15 INFO TaskSetManager: Starting task 1.0 in stage 0.0 (TID 1) (51f90827d3d2, executor driver, partition 1, PROCESS_LOCAL, 7395 bytes)
# 24/01/12 16:43:15 INFO Executor: Running task 1.0 in stage 0.0 (TID 1)
# 24/01/12 16:43:15 INFO Executor: Running task 0.0 in stage 0.0 (TID 0)
# 24/01/12 16:43:15 INFO HadoopRDD: Input split: file:/content/miEntrada.txt:0+59
# 24/01/12 16:43:15 INFO HadoopRDD: Input split: file:/content/miEntrada.txt:59+59
# 24/01/12 16:43:17 INFO PythonRunner: Times: total = 906, boot = 773, init = 133, finish = 0
# 24/01/12 16:43:17 INFO PythonRunner: Times: total = 914, boot = 775, init = 139, finish = 0
# 24/01/12 16:43:17 INFO Executor: Finished task 1.0 in stage 0.0 (TID 1). 1624 bytes result sent to driver
# 24/01/12 16:43:17 INFO Executor: Finished task 0.0 in stage 0.0 (TID 0). 1624 bytes result sent to driver
# 24/01/12 16:43:17 INFO TaskSetManager: Finished task 0.0 in stage 0.0 (TID 0) in 1836 ms on 51f90827d3d2 (executor driver) (1/2)
# 24/01/12 16:43:17 INFO TaskSetManager: Finished task 1.0 in stage 0.0 (TID 1) in 1813 ms on 51f90827d3d2 (executor driver) (2/2)
# 24/01/12 16:43:17 INFO TaskSchedulerImpl: Removed TaskSet 0.0, whose tasks have all completed, from pool
# 24/01/12 16:43:17 INFO PythonAccumulatorV2: Connected to AccumulatorServer at host: 127.0.0.1 port: 46991
# 24/01/12 16:43:17 INFO DAGScheduler: ShuffleMapStage 0 (reduceByKey at /content/A2Ej1.py:29) finished in 2.019 s
# 24/01/12 16:43:17 INFO DAGScheduler: looking for newly runnable stages
# 24/01/12 16:43:17 INFO DAGScheduler: running: Set()
# 24/01/12 16:43:17 INFO DAGScheduler: waiting: Set(ResultStage 1)
# 24/01/12 16:43:17 INFO DAGScheduler: failed: Set()
# 24/01/12 16:43:17 INFO DAGScheduler: Submitting ResultStage 1 (MapPartitionsRDD[8] at saveAsTextFile at NativeMethodAccessorImpl.java:0), which has no missing parents
# 24/01/12 16:43:17 INFO MemoryStore: Block broadcast_2 stored as values in memory (estimated size 108.4 KiB, free 365.8 MiB)
# 24/01/12 16:43:17 INFO MemoryStore: Block broadcast_2_piece0 stored as bytes in memory (estimated size 41.0 KiB, free 365.8 MiB)
# 24/01/12 16:43:17 INFO BlockManagerInfo: Added broadcast_2_piece0 in memory on 51f90827d3d2:40947 (size: 41.0 KiB, free: 366.2 MiB)
# 24/01/12 16:43:17 INFO SparkContext: Created broadcast 2 from broadcast at DAGScheduler.scala:1535
# 24/01/12 16:43:17 INFO DAGScheduler: Submitting 2 missing tasks from ResultStage 1 (MapPartitionsRDD[8] at saveAsTextFile at NativeMethodAccessorImpl.java:0) (first 15 tasks are for partitions Vector(0, 1))
# 24/01/12 16:43:17 INFO TaskSchedulerImpl: Adding task set 1.0 with 2 tasks resource profile 0
# 24/01/12 16:43:17 INFO TaskSetManager: Starting task 1.0 in stage 1.0 (TID 2) (51f90827d3d2, executor driver, partition 1, NODE_LOCAL, 7181 bytes)
# 24/01/12 16:43:17 INFO TaskSetManager: Starting task 0.0 in stage 1.0 (TID 3) (51f90827d3d2, executor driver, partition 0, PROCESS_LOCAL, 7181 bytes)
# 24/01/12 16:43:17 INFO Executor: Running task 1.0 in stage 1.0 (TID 2)
# 24/01/12 16:43:17 INFO Executor: Running task 0.0 in stage 1.0 (TID 3)
# 24/01/12 16:43:17 INFO ShuffleBlockFetcherIterator: Getting 0 (0.0 B) non-empty blocks including 0 (0.0 B) local and 0 (0.0 B) host-local and 0 (0.0 B) push-merged-local and 0 (0.0 B) remote blocks
# 24/01/12 16:43:17 INFO ShuffleBlockFetcherIterator: Getting 2 (194.0 B) non-empty blocks including 2 (194.0 B) local and 0 (0.0 B) host-local and 0 (0.0 B) push-merged-local and 0 (0.0 B) remote blocks
# 24/01/12 16:43:17 INFO ShuffleBlockFetcherIterator: Started 0 remote fetches in 23 ms
# 24/01/12 16:43:17 INFO ShuffleBlockFetcherIterator: Started 0 remote fetches in 26 ms
# 24/01/12 16:43:17 INFO HadoopMapRedCommitProtocol: Using output committer class org.apache.hadoop.mapred.FileOutputCommitter
# 24/01/12 16:43:17 INFO FileOutputCommitter: File Output Committer Algorithm version is 1
# 24/01/12 16:43:17 INFO FileOutputCommitter: FileOutputCommitter skip cleanup _temporary folders under output directory:false, ignore cleanup failures: false
# 24/01/12 16:43:17 INFO HadoopMapRedCommitProtocol: Using output committer class org.apache.hadoop.mapred.FileOutputCommitter
# 24/01/12 16:43:17 INFO FileOutputCommitter: File Output Committer Algorithm version is 1
# 24/01/12 16:43:17 INFO FileOutputCommitter: FileOutputCommitter skip cleanup _temporary folders under output directory:false, ignore cleanup failures: false
# 24/01/12 16:43:17 INFO PythonRunner: Times: total = 155, boot = -673, init = 828, finish = 0
# 24/01/12 16:43:17 INFO FileOutputCommitter: Saved output of task 'attempt_202401121643144251204270832138051_0008_m_000000_0' to file:/content/Salida/_temporary/0/task_202401121643144251204270832138051_0008_m_000000
# 24/01/12 16:43:17 INFO SparkHadoopMapRedUtil: attempt_202401121643144251204270832138051_0008_m_000000_0: Committed. Elapsed time: 8 ms.
# 24/01/12 16:43:17 INFO PythonRunner: Times: total = 180, boot = -683, init = 863, finish = 0
# 24/01/12 16:43:17 INFO FileOutputCommitter: Saved output of task 'attempt_202401121643144251204270832138051_0008_m_000001_0' to file:/content/Salida/_temporary/0/task_202401121643144251204270832138051_0008_m_000001
# 24/01/12 16:43:17 INFO SparkHadoopMapRedUtil: attempt_202401121643144251204270832138051_0008_m_000001_0: Committed. Elapsed time: 0 ms.
# 24/01/12 16:43:17 INFO Executor: Finished task 1.0 in stage 1.0 (TID 2). 2351 bytes result sent to driver
# 24/01/12 16:43:17 INFO TaskSetManager: Finished task 1.0 in stage 1.0 (TID 2) in 370 ms on 51f90827d3d2 (executor driver) (1/2)
# 24/01/12 16:43:17 INFO Executor: Finished task 0.0 in stage 1.0 (TID 3). 2308 bytes result sent to driver
# 24/01/12 16:43:17 INFO TaskSetManager: Finished task 0.0 in stage 1.0 (TID 3) in 383 ms on 51f90827d3d2 (executor driver) (2/2)
# 24/01/12 16:43:17 INFO TaskSchedulerImpl: Removed TaskSet 1.0, whose tasks have all completed, from pool
# 24/01/12 16:43:17 INFO DAGScheduler: ResultStage 1 (runJob at SparkHadoopWriter.scala:83) finished in 0.434 s
# 24/01/12 16:43:17 INFO DAGScheduler: Job 0 is finished. Cancelling potential speculative or zombie tasks for this job
# 24/01/12 16:43:17 INFO TaskSchedulerImpl: Killing all running tasks in stage 1: Stage finished
# 24/01/12 16:43:17 INFO DAGScheduler: Job 0 finished: runJob at SparkHadoopWriter.scala:83, took 2.771084 s
# 24/01/12 16:43:17 INFO SparkHadoopWriter: Start to commit write Job job_202401121643144251204270832138051_0008.
# 24/01/12 16:43:17 INFO SparkHadoopWriter: Write Job job_202401121643144251204270832138051_0008 committed. Elapsed time: 37 ms.
# 24/01/12 16:43:17 INFO SparkContext: SparkContext is stopping with exitCode 0.
# 24/01/12 16:43:17 INFO SparkUI: Stopped Spark web UI at http://51f90827d3d2:4040
# 24/01/12 16:43:17 INFO MapOutputTrackerMasterEndpoint: MapOutputTrackerMasterEndpoint stopped!
# 24/01/12 16:43:17 INFO MemoryStore: MemoryStore cleared
# 24/01/12 16:43:17 INFO BlockManager: BlockManager stopped
# 24/01/12 16:43:17 INFO BlockManagerMaster: BlockManagerMaster stopped
# 24/01/12 16:43:17 INFO OutputCommitCoordinator$OutputCommitCoordinatorEndpoint: OutputCommitCoordinator stopped!
# 24/01/12 16:43:17 INFO SparkContext: Successfully stopped SparkContext
# 24/01/12 16:43:18 INFO ShutdownHookManager: Shutdown hook called
# 24/01/12 16:43:18 INFO ShutdownHookManager: Deleting directory /tmp/spark-a7860482-f27d-4329-820f-152b07585758/pyspark-2e210678-96b9-4056-ba46-9393f77e14df
# 24/01/12 16:43:18 INFO ShutdownHookManager: Deleting directory /tmp/spark-a7860482-f27d-4329-820f-152b07585758
# 24/01/12 16:43:18 INFO ShutdownHookManager: Deleting directory /tmp/spark-9ccf4980-c689-4fb5-9b9a-a2b943c166a5

# %%
# !cat Salida/*
# Out:
# ('Alice', 250.0)
# ('Bob', 201.0)
# ('Luis', 0)

# %%
#Ejecutamos el programa con otro dataset más largo
# !$SPARK_HOME/bin/spark-submit /content/A2Ej1.py /content/miEntradaLarga.txt /content/SalidaLarga3
# Out:
# 24/01/11 19:25:58 INFO SparkContext: Running Spark version 3.4.2
# 24/01/11 19:25:58 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# 24/01/11 19:25:59 INFO ResourceUtils: ==============================================================
# 24/01/11 19:25:59 INFO ResourceUtils: No custom resources configured for spark.driver.
# 24/01/11 19:25:59 INFO ResourceUtils: ==============================================================
# 24/01/11 19:25:59 INFO SparkContext: Submitted application: personaGastosConTarjetaCredito
# 24/01/11 19:25:59 INFO ResourceProfile: Default ResourceProfile created, executor resources: Map(cores -> name: cores, amount: 1, script: , vendor: , memory -> name: memory, amount: 1024, script: , vendor: , offHeap -> name: offHeap, amount: 0, script: , vendor: ), task resources: Map(cpus -> name: cpus, amount: 1.0)
# 24/01/11 19:25:59 INFO ResourceProfile: Limiting resource is cpu
# 24/01/11 19:25:59 INFO ResourceProfileManager: Added ResourceProfile id: 0
# 24/01/11 19:25:59 INFO SecurityManager: Changing view acls to: root
# 24/01/11 19:25:59 INFO SecurityManager: Changing modify acls to: root
# 24/01/11 19:25:59 INFO SecurityManager: Changing view acls groups to:
# 24/01/11 19:25:59 INFO SecurityManager: Changing modify acls groups to:
# 24/01/11 19:25:59 INFO SecurityManager: SecurityManager: authentication disabled; ui acls disabled; users with view permissions: root; groups with view permissions: EMPTY; users with modify permissions: root; groups with modify permissions: EMPTY
# 24/01/11 19:25:59 INFO Utils: Successfully started service 'sparkDriver' on port 46435.
# 24/01/11 19:25:59 INFO SparkEnv: Registering MapOutputTracker
# 24/01/11 19:26:00 INFO SparkEnv: Registering BlockManagerMaster
# 24/01/11 19:26:00 INFO BlockManagerMasterEndpoint: Using org.apache.spark.storage.DefaultTopologyMapper for getting topology information
# 24/01/11 19:26:00 INFO BlockManagerMasterEndpoint: BlockManagerMasterEndpoint up
# 24/01/11 19:26:00 INFO SparkEnv: Registering BlockManagerMasterHeartbeat
# 24/01/11 19:26:00 INFO DiskBlockManager: Created local directory at /tmp/blockmgr-2d397be7-5533-432b-b88d-90f572f16fc5
# 24/01/11 19:26:00 INFO MemoryStore: MemoryStore started with capacity 366.3 MiB
# 24/01/11 19:26:00 INFO SparkEnv: Registering OutputCommitCoordinator
# 24/01/11 19:26:00 INFO JettyUtils: Start Jetty 0.0.0.0:4040 for SparkUI
# 24/01/11 19:26:00 INFO Utils: Successfully started service 'SparkUI' on port 4040.
# 24/01/11 19:26:00 INFO Executor: Starting executor ID driver on host 9ad1608dd5ef
# 24/01/11 19:26:00 INFO Executor: Starting executor with user classpath (userClassPathFirst = false): ''
# 24/01/11 19:26:01 INFO Utils: Successfully started service 'org.apache.spark.network.netty.NettyBlockTransferService' on port 42333.
# 24/01/11 19:26:01 INFO NettyBlockTransferService: Server created on 9ad1608dd5ef:42333
# 24/01/11 19:26:01 INFO BlockManager: Using org.apache.spark.storage.RandomBlockReplicationPolicy for block replication policy
# 24/01/11 19:26:01 INFO BlockManagerMaster: Registering BlockManager BlockManagerId(driver, 9ad1608dd5ef, 42333, None)
# 24/01/11 19:26:01 INFO BlockManagerMasterEndpoint: Registering block manager 9ad1608dd5ef:42333 with 366.3 MiB RAM, BlockManagerId(driver, 9ad1608dd5ef, 42333, None)
# 24/01/11 19:26:01 INFO BlockManagerMaster: Registered BlockManager BlockManagerId(driver, 9ad1608dd5ef, 42333, None)
# 24/01/11 19:26:01 INFO BlockManager: Initialized BlockManager: BlockManagerId(driver, 9ad1608dd5ef, 42333, None)
# 24/01/11 19:26:02 INFO MemoryStore: Block broadcast_0 stored as values in memory (estimated size 358.0 KiB, free 366.0 MiB)
# 24/01/11 19:26:02 INFO MemoryStore: Block broadcast_0_piece0 stored as bytes in memory (estimated size 32.5 KiB, free 365.9 MiB)
# 24/01/11 19:26:02 INFO BlockManagerInfo: Added broadcast_0_piece0 in memory on 9ad1608dd5ef:42333 (size: 32.5 KiB, free: 366.3 MiB)
# 24/01/11 19:26:02 INFO SparkContext: Created broadcast 0 from textFile at NativeMethodAccessorImpl.java:0
# 24/01/11 19:26:03 INFO FileInputFormat: Total input files to process : 1
# 24/01/11 19:26:03 INFO deprecation: mapred.output.dir is deprecated. Instead, use mapreduce.output.fileoutputformat.outputdir
# 24/01/11 19:26:03 INFO HadoopMapRedCommitProtocol: Using output committer class org.apache.hadoop.mapred.FileOutputCommitter
# 24/01/11 19:26:03 INFO FileOutputCommitter: File Output Committer Algorithm version is 1
# 24/01/11 19:26:03 INFO FileOutputCommitter: FileOutputCommitter skip cleanup _temporary folders under output directory:false, ignore cleanup failures: false
# 24/01/11 19:26:03 INFO SparkContext: Starting job: runJob at SparkHadoopWriter.scala:83
# 24/01/11 19:26:04 INFO DAGScheduler: Registering RDD 3 (reduceByKey at /content/A2Ej1.py:29) as input to shuffle 0
# 24/01/11 19:26:04 INFO DAGScheduler: Got job 0 (runJob at SparkHadoopWriter.scala:83) with 2 output partitions
# 24/01/11 19:26:04 INFO DAGScheduler: Final stage: ResultStage 1 (runJob at SparkHadoopWriter.scala:83)
# 24/01/11 19:26:04 INFO DAGScheduler: Parents of final stage: List(ShuffleMapStage 0)
# 24/01/11 19:26:04 INFO DAGScheduler: Missing parents: List(ShuffleMapStage 0)
# 24/01/11 19:26:04 INFO DAGScheduler: Submitting ShuffleMapStage 0 (PairwiseRDD[3] at reduceByKey at /content/A2Ej1.py:29), which has no missing parents
# 24/01/11 19:26:04 INFO MemoryStore: Block broadcast_1 stored as values in memory (estimated size 12.1 KiB, free 365.9 MiB)
# 24/01/11 19:26:04 INFO MemoryStore: Block broadcast_1_piece0 stored as bytes in memory (estimated size 7.5 KiB, free 365.9 MiB)
# 24/01/11 19:26:04 INFO BlockManagerInfo: Added broadcast_1_piece0 in memory on 9ad1608dd5ef:42333 (size: 7.5 KiB, free: 366.3 MiB)
# 24/01/11 19:26:04 INFO SparkContext: Created broadcast 1 from broadcast at DAGScheduler.scala:1535
# 24/01/11 19:26:04 INFO DAGScheduler: Submitting 2 missing tasks from ShuffleMapStage 0 (PairwiseRDD[3] at reduceByKey at /content/A2Ej1.py:29) (first 15 tasks are for partitions Vector(0, 1))
# 24/01/11 19:26:04 INFO TaskSchedulerImpl: Adding task set 0.0 with 2 tasks resource profile 0
# 24/01/11 19:26:04 INFO TaskSetManager: Starting task 0.0 in stage 0.0 (TID 0) (9ad1608dd5ef, executor driver, partition 0, PROCESS_LOCAL, 7400 bytes)
# 24/01/11 19:26:04 INFO TaskSetManager: Starting task 1.0 in stage 0.0 (TID 1) (9ad1608dd5ef, executor driver, partition 1, PROCESS_LOCAL, 7400 bytes)
# 24/01/11 19:26:04 INFO Executor: Running task 1.0 in stage 0.0 (TID 1)
# 24/01/11 19:26:04 INFO Executor: Running task 0.0 in stage 0.0 (TID 0)
# 24/01/11 19:26:05 INFO HadoopRDD: Input split: file:/content/miEntradaLarga.txt:0+2461
# 24/01/11 19:26:05 INFO HadoopRDD: Input split: file:/content/miEntradaLarga.txt:2461+2461
# 24/01/11 19:26:07 INFO PythonRunner: Times: total = 1384, boot = 1089, init = 293, finish = 2
# 24/01/11 19:26:07 INFO PythonRunner: Times: total = 1480, boot = 1091, init = 387, finish = 2
# 24/01/11 19:26:07 INFO Executor: Finished task 1.0 in stage 0.0 (TID 1). 1624 bytes result sent to driver
# 24/01/11 19:26:07 INFO Executor: Finished task 0.0 in stage 0.0 (TID 0). 1624 bytes result sent to driver
# 24/01/11 19:26:07 INFO TaskSetManager: Finished task 1.0 in stage 0.0 (TID 1) in 3038 ms on 9ad1608dd5ef (executor driver) (1/2)
# 24/01/11 19:26:07 INFO TaskSetManager: Finished task 0.0 in stage 0.0 (TID 0) in 3103 ms on 9ad1608dd5ef (executor driver) (2/2)
# 24/01/11 19:26:07 INFO TaskSchedulerImpl: Removed TaskSet 0.0, whose tasks have all completed, from pool
# 24/01/11 19:26:07 INFO PythonAccumulatorV2: Connected to AccumulatorServer at host: 127.0.0.1 port: 45571
# 24/01/11 19:26:07 INFO DAGScheduler: ShuffleMapStage 0 (reduceByKey at /content/A2Ej1.py:29) finished in 3.448 s
# 24/01/11 19:26:07 INFO DAGScheduler: looking for newly runnable stages
# 24/01/11 19:26:07 INFO DAGScheduler: running: Set()
# 24/01/11 19:26:07 INFO DAGScheduler: waiting: Set(ResultStage 1)
# 24/01/11 19:26:07 INFO DAGScheduler: failed: Set()
# 24/01/11 19:26:07 INFO DAGScheduler: Submitting ResultStage 1 (MapPartitionsRDD[8] at saveAsTextFile at NativeMethodAccessorImpl.java:0), which has no missing parents
# 24/01/11 19:26:07 INFO MemoryStore: Block broadcast_2 stored as values in memory (estimated size 108.5 KiB, free 365.8 MiB)
# 24/01/11 19:26:07 INFO MemoryStore: Block broadcast_2_piece0 stored as bytes in memory (estimated size 41.0 KiB, free 365.8 MiB)
# 24/01/11 19:26:07 INFO BlockManagerInfo: Added broadcast_2_piece0 in memory on 9ad1608dd5ef:42333 (size: 41.0 KiB, free: 366.2 MiB)
# 24/01/11 19:26:07 INFO SparkContext: Created broadcast 2 from broadcast at DAGScheduler.scala:1535
# 24/01/11 19:26:07 INFO DAGScheduler: Submitting 2 missing tasks from ResultStage 1 (MapPartitionsRDD[8] at saveAsTextFile at NativeMethodAccessorImpl.java:0) (first 15 tasks are for partitions Vector(0, 1))
# 24/01/11 19:26:07 INFO TaskSchedulerImpl: Adding task set 1.0 with 2 tasks resource profile 0
# 24/01/11 19:26:07 INFO TaskSetManager: Starting task 0.0 in stage 1.0 (TID 2) (9ad1608dd5ef, executor driver, partition 0, NODE_LOCAL, 7181 bytes)
# 24/01/11 19:26:07 INFO TaskSetManager: Starting task 1.0 in stage 1.0 (TID 3) (9ad1608dd5ef, executor driver, partition 1, NODE_LOCAL, 7181 bytes)
# 24/01/11 19:26:07 INFO Executor: Running task 0.0 in stage 1.0 (TID 2)
# 24/01/11 19:26:07 INFO Executor: Running task 1.0 in stage 1.0 (TID 3)
# 24/01/11 19:26:08 INFO ShuffleBlockFetcherIterator: Getting 2 (194.0 B) non-empty blocks including 2 (194.0 B) local and 0 (0.0 B) host-local and 0 (0.0 B) push-merged-local and 0 (0.0 B) remote blocks
# 24/01/11 19:26:08 INFO ShuffleBlockFetcherIterator: Getting 2 (214.0 B) non-empty blocks including 2 (214.0 B) local and 0 (0.0 B) host-local and 0 (0.0 B) push-merged-local and 0 (0.0 B) remote blocks
# 24/01/11 19:26:08 INFO ShuffleBlockFetcherIterator: Started 0 remote fetches in 22 ms
# 24/01/11 19:26:08 INFO ShuffleBlockFetcherIterator: Started 0 remote fetches in 53 ms
# 24/01/11 19:26:08 INFO HadoopMapRedCommitProtocol: Using output committer class org.apache.hadoop.mapred.FileOutputCommitter
# 24/01/11 19:26:08 INFO FileOutputCommitter: File Output Committer Algorithm version is 1
# 24/01/11 19:26:08 INFO FileOutputCommitter: FileOutputCommitter skip cleanup _temporary folders under output directory:false, ignore cleanup failures: false
# 24/01/11 19:26:08 INFO HadoopMapRedCommitProtocol: Using output committer class org.apache.hadoop.mapred.FileOutputCommitter
# 24/01/11 19:26:08 INFO FileOutputCommitter: File Output Committer Algorithm version is 1
# 24/01/11 19:26:08 INFO FileOutputCommitter: FileOutputCommitter skip cleanup _temporary folders under output directory:false, ignore cleanup failures: false
# 24/01/11 19:26:08 INFO PythonRunner: Times: total = 590, boot = -1352, init = 1942, finish = 0
# 24/01/11 19:26:08 INFO PythonRunner: Times: total = 604, boot = -1268, init = 1870, finish = 2
# 24/01/11 19:26:08 INFO FileOutputCommitter: Saved output of task 'attempt_202401111926036418120697910103462_0008_m_000001_0' to file:/content/SalidaLarga3/_temporary/0/task_202401111926036418120697910103462_0008_m_000001
# 24/01/11 19:26:08 INFO SparkHadoopMapRedUtil: attempt_202401111926036418120697910103462_0008_m_000001_0: Committed. Elapsed time: 2 ms.
# 24/01/11 19:26:08 INFO FileOutputCommitter: Saved output of task 'attempt_202401111926036418120697910103462_0008_m_000000_0' to file:/content/SalidaLarga3/_temporary/0/task_202401111926036418120697910103462_0008_m_000000
# 24/01/11 19:26:08 INFO SparkHadoopMapRedUtil: attempt_202401111926036418120697910103462_0008_m_000000_0: Committed. Elapsed time: 4 ms.
# 24/01/11 19:26:08 INFO Executor: Finished task 1.0 in stage 1.0 (TID 3). 2394 bytes result sent to driver
# 24/01/11 19:26:08 INFO Executor: Finished task 0.0 in stage 1.0 (TID 2). 2394 bytes result sent to driver
# 24/01/11 19:26:08 INFO TaskSetManager: Finished task 1.0 in stage 1.0 (TID 3) in 1013 ms on 9ad1608dd5ef (executor driver) (1/2)
# 24/01/11 19:26:08 INFO TaskSetManager: Finished task 0.0 in stage 1.0 (TID 2) in 1034 ms on 9ad1608dd5ef (executor driver) (2/2)
# 24/01/11 19:26:08 INFO DAGScheduler: ResultStage 1 (runJob at SparkHadoopWriter.scala:83) finished in 1.139 s
# 24/01/11 19:26:08 INFO TaskSchedulerImpl: Removed TaskSet 1.0, whose tasks have all completed, from pool
# 24/01/11 19:26:08 INFO DAGScheduler: Job 0 is finished. Cancelling potential speculative or zombie tasks for this job
# 24/01/11 19:26:08 INFO TaskSchedulerImpl: Killing all running tasks in stage 1: Stage finished
# 24/01/11 19:26:08 INFO DAGScheduler: Job 0 finished: runJob at SparkHadoopWriter.scala:83, took 5.214729 s
# 24/01/11 19:26:08 INFO SparkHadoopWriter: Start to commit write Job job_202401111926036418120697910103462_0008.
# 24/01/11 19:26:08 INFO SparkHadoopWriter: Write Job job_202401111926036418120697910103462_0008 committed. Elapsed time: 65 ms.
# 24/01/11 19:26:08 INFO SparkContext: SparkContext is stopping with exitCode 0.
# 24/01/11 19:26:09 INFO SparkUI: Stopped Spark web UI at http://9ad1608dd5ef:4040
# 24/01/11 19:26:09 INFO MapOutputTrackerMasterEndpoint: MapOutputTrackerMasterEndpoint stopped!
# 24/01/11 19:26:09 INFO MemoryStore: MemoryStore cleared
# 24/01/11 19:26:09 INFO BlockManager: BlockManager stopped
# 24/01/11 19:26:09 INFO BlockManagerMaster: BlockManagerMaster stopped
# 24/01/11 19:26:09 INFO OutputCommitCoordinator$OutputCommitCoordinatorEndpoint: OutputCommitCoordinator stopped!
# 24/01/11 19:26:09 INFO SparkContext: Successfully stopped SparkContext
# 24/01/11 19:26:09 INFO ShutdownHookManager: Shutdown hook called
# 24/01/11 19:26:09 INFO ShutdownHookManager: Deleting directory /tmp/spark-814d7108-67f8-4863-b41d-6c0983d636e5
# 24/01/11 19:26:09 INFO ShutdownHookManager: Deleting directory /tmp/spark-d3fe3491-18ae-4889-a533-c588e7c46a64
# 24/01/11 19:26:09 INFO ShutdownHookManager: Deleting directory /tmp/spark-d3fe3491-18ae-4889-a533-c588e7c46a64/pyspark-3160f63c-3439-4098-b3fb-959472336101

# %%
#Comprobamos el fichero de salida
# !cat SalidaLarga3/*
# Out:
# ('Saioa', 9022.25)
# ('Xabi', 0)
# ('Alice', 400.0)
# ('Bob', 8243.5)
# ('Luis', 0)

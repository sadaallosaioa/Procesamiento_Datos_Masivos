# %%
#Instalamos Java
# !apt-get install openjdk-8-jdk-headless --quiet > /dev/null

# %%
#.Descargamos Spark: para ello tenemos que indicar:
# !wget --quiet https://dlcdn.apache.org/spark/spark-3.4.2/spark-3.4.2-bin-hadoop3.tgz

# %%
#descomprima Hadoop:
# !tar xf spark-3.4.2-bin-hadoop3.tgz

# %%
#Creamos las variables de entorno de java y Spark. Para ello creamos una nueva nota con lo siguiente:
import os
os.environ["JAVA_HOME"] = "/usr/lib/jvm/java-8-openjdk-amd64"
os.environ["SPARK_HOME"] = "/content/spark-3.4.2-bin-hadoop3"

# %%
#Instalamos findspark para que nos permita importar pyspark de forma sencilla como una librería:
# !pip install --quiet findspark

# %%
#Iniciamos findspark:
import findspark
findspark.init()

# %% [markdown]
# (Subir los archivos)

# %%
# !$SPARK_HOME/bin/spark-submit /content/personaYMetodosDePago.py /content/entrada.txt /content/comprasSinTDCMayorDe1500 /content/comprasSinTDCMenoroIgualDe1500
# Out:
# 24/01/14 11:59:35 INFO SparkContext: Running Spark version 3.4.2
# 24/01/14 11:59:35 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# 24/01/14 11:59:35 INFO ResourceUtils: ==============================================================
# 24/01/14 11:59:35 INFO ResourceUtils: No custom resources configured for spark.driver.
# 24/01/14 11:59:35 INFO ResourceUtils: ==============================================================
# 24/01/14 11:59:35 INFO SparkContext: Submitted application: comprasSinTDCMayorDe1500
# 24/01/14 11:59:35 INFO ResourceProfile: Default ResourceProfile created, executor resources: Map(cores -> name: cores, amount: 1, script: , vendor: , memory -> name: memory, amount: 1024, script: , vendor: , offHeap -> name: offHeap, amount: 0, script: , vendor: ), task resources: Map(cpus -> name: cpus, amount: 1.0)
# 24/01/14 11:59:35 INFO ResourceProfile: Limiting resource is cpu
# ...

# %%
# !cat comprasSinTDCMayorDe1500/*
# Out:
# ('Alice', 0)
# ('Bob', 1)

# %%
# !cat comprasSinTDCMenoroIgualDe1500/*
# Out:
# ('Alice', 1)
# ('Bob', 0)

# %%
# !$SPARK_HOME/bin/spark-submit /content/personaYMetodosDePago.py /content/miEntradaLarga.txt /content/LargaSinTDCMayor /content/LargaSinTDCMenoroIgual
# Out:
# 24/01/14 12:11:18 INFO SparkContext: Running Spark version 3.4.2
# 24/01/14 12:11:18 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# 24/01/14 12:11:18 INFO ResourceUtils: ==============================================================
# 24/01/14 12:11:18 INFO ResourceUtils: No custom resources configured for spark.driver.
# 24/01/14 12:11:18 INFO ResourceUtils: ==============================================================
# 24/01/14 12:11:18 INFO SparkContext: Submitted application: comprasSinTDCMayorDe1500
# 24/01/14 12:11:18 INFO ResourceProfile: Default ResourceProfile created, executor resources: Map(cores -> name: cores, amount: 1, script: , vendor: , memory -> name: memory, amount: 1024, script: , vendor: , offHeap -> name: offHeap, amount: 0, script: , vendor: ), task resources: Map(cpus -> name: cpus, amount: 1.0)
# 24/01/14 12:11:18 INFO ResourceProfile: Limiting resource is cpu
# ...

# %%
# !cat LargaSinTDCMayor/*
# Out:
# ('Saioa', 0)
# ('Xabi', 40)
# ('Alice', 0)
# ('Bob', 0)
# ('Luis', 0)

# %%
# !cat LargaSinTDCMenoroIgual/*
# Out:
# ('Saioa', 1)
# ('Xabi', 0)
# ('Alice', 2)
# ('Bob', 0)
# ('Luis', 41)

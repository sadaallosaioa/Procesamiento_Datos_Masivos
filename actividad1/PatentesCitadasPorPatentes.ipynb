# %% [markdown]
# # Instalaciones previas

# %% [markdown]
# 1. Instalamos java:

# %%
# !apt-get install -y openjdk-11-jdk-headless -qq > /dev/null

# %% [markdown]
# 2. Descargamos Hadoop: (versión 3.3.5)

# %%
# !wget https://downloads.apache.org/hadoop/common/hadoop-3.3.5/hadoop-3.3.5.tar.gz
# Out:
# --2024-01-08 13:53:32--  https://downloads.apache.org/hadoop/common/hadoop-3.3.5/hadoop-3.3.5.tar.gz
# Resolving downloads.apache.org (downloads.apache.org)... 135.181.214.104, 88.99.95.219, 2a01:4f8:10a:201a::2, ...
# Connecting to downloads.apache.org (downloads.apache.org)|135.181.214.104|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 706533213 (674M) [application/x-gzip]
# Saving to: ‘hadoop-3.3.5.tar.gz’
#
# hadoop-3.3.5.tar.gz 100%[===================>] 673.80M  26.0MB/s    in 27s
#
# 2024-01-08 13:53:59 (24.7 MB/s) - ‘hadoop-3.3.5.tar.gz’ saved [706533213/706533213]

# %% [markdown]
# 3. Descomprimimimos y movemos a /usr/local:

# %%
# !tar -xzf hadoop-3.3.5.tar.gz
# !mv hadoop-3.3.5/ /usr/local/

# %% [markdown]
# 4. Creamos las variables de entorno de java y hadoop:

# %%
import os
os.environ["JAVA_HOME"] = "/usr/lib/jvm/java-11-openjdk-amd64"
os.environ["HADOOP_HOME"] = "/usr/local/hadoop-3.3.5"
os.environ["PATH"] += os.pathsep + "/usr/local/hadoop-3.3.5/bin"

# %% [markdown]
# # Ejercicio 2
# Subimos el archivo de los datos y los programas Mapper, Combiner y Reducer a collab:
# (**Clicando en la parte izquierda** de archivos...)

# %% [markdown]
# 1. Le damos permisos de ejecución a los programas Mapper, Combiner y Reducer_

# %%
# !chmod u+x ./A1Ej2Map.py
# !chmod u+x ./A1Ej2Red.py

# %% [markdown]
# 2. Ejecutamos el programa:

# %%
# !hadoop jar $HADOOP_HOME/share/hadoop/tools/lib/hadoop-streaming-3.3.5.jar \
-files ./A1Ej2Map.py \
-files ./A1Ej1Red.py \
-mapper ./A1Ej2Map.py \
-reducer ./A1Ej2Red.py \
-input cite75_99capada.txt \
-output ./salida
# Out:
# 2024-01-08 14:05:12,784 INFO impl.MetricsConfig: Loaded properties from hadoop-metrics2.properties
# 2024-01-08 14:05:13,100 INFO impl.MetricsSystemImpl: Scheduled Metric snapshot period at 10 second(s).
# 2024-01-08 14:05:13,100 INFO impl.MetricsSystemImpl: JobTracker metrics system started
# 2024-01-08 14:05:13,131 WARN impl.MetricsSystemImpl: JobTracker metrics system already initialized!
# 2024-01-08 14:05:13,562 INFO mapred.FileInputFormat: Total input files to process : 1
# 2024-01-08 14:05:13,602 INFO mapreduce.JobSubmitter: number of splits:1
# 2024-01-08 14:05:14,092 INFO mapreduce.JobSubmitter: Submitting tokens for job: job_local2107689945_0001
# 2024-01-08 14:05:14,092 INFO mapreduce.JobSubmitter: Executing with tokens: []
# 2024-01-08 14:05:14,612 INFO mapred.LocalDistributedCacheManager: Localized file:/content/A1Ej2Map.py as file:/tmp/hadoop-root/mapred/local/job_local2107689945_0001_55afab89-7d2e-4d08-b683-84b4aa71f57e/A1Ej2Map.py
# ...

# %%
# !head ./salida/*
# Out:
# ==> ./salida/part-00000 <==
# 1000185	3871143
# 1000213	3866664
# 1000335	3898429
# 1000430	3896637
# 1000491	3885321
# 1000498	3893619
# 1000608	3864237
# 1000715	3861270
# 1000721	3892234
# 1000736	3878852
#
# ==> ./salida/_SUCCESS <==

# %%
# !cat ./salida/*
# Out:
# Se han truncado las últimas 5000 líneas del flujo de salida.
# 3577357	3867319,3870662
# 3577363	3867495
# 3577365	3864301,3896067
# 3577371	3876583
# 3577372	3860543
# 3577398	3872064,3880953
# 3577399	3884891
# 3577400	3865800,3884893
# 3577409	3875150
# 3577431	3860610
# 3577441	3872113
# 3577444	3877935
# 3577446	3875196
# 3577453	3862976,3890383
# 3577473	3897509
# 3577477	3887631
# 3577478	3880950
# 3577480	3875258
# 3577482	3862273
# 3577483	3888953
# 3577488	3875281,3884748
# 3577491	3885027
# 3577512	3859169,3860701,3871964
# 3577515	3878121,3886085,3895980
# 3577516	3868447,3880158,3888782
# 3577517	3860699
# 3577518	3893988
# 3577519	3880977
# 3577522	3893990
# 3577534	3865723
# 3577548	3888982,3891767
# 3577567	3879769
# 3577572	3859675
# 3577574	3874423
# 3577593	3898315
# 3577597	3883047
# 3577610	3880979
# 3577614	3863309
# 3577619	3861012
# 3577637	3879847
# 3577638	3861250
# 3577642	3889520
# 3577646	3890718
# 3577665	3873082
# 3577669	3878636
# 3577672	3898776
# ...

# %% [markdown]
# Intentaré ejecutar implementar el programa MapReduce sobre el archivo completo, que tengo guardado en mi Drive.
# Para ello, primero monto el Drive:

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !hadoop fs -copyFromLocal '/content/drive/MyDrive/03Procesamientos/Actividad1/Ejercicio2/cite75_99.txt' '/content/entrada.txt'

# %%
# !hadoop jar $HADOOP_HOME/share/hadoop/tools/lib/hadoop-streaming-3.3.5.jar \
-files ./A1Ej2Map.py \
-files ./A1Ej1Red.py \
-mapper ./A1Ej2Map.py \
-reducer ./A1Ej2Red.py \
-input entrada.txt \
-output ./salida2
# Out:
# 2024-01-08 16:08:59,237 INFO impl.MetricsConfig: Loaded properties from hadoop-metrics2.properties
# 2024-01-08 16:08:59,528 INFO impl.MetricsSystemImpl: Scheduled Metric snapshot period at 10 second(s).
# 2024-01-08 16:08:59,528 INFO impl.MetricsSystemImpl: JobTracker metrics system started
# 2024-01-08 16:08:59,592 WARN impl.MetricsSystemImpl: JobTracker metrics system already initialized!
# 2024-01-08 16:09:00,218 INFO mapred.FileInputFormat: Total input files to process : 1
# 2024-01-08 16:09:00,258 INFO mapreduce.JobSubmitter: number of splits:8
# 2024-01-08 16:09:00,797 INFO mapreduce.JobSubmitter: Submitting tokens for job: job_local280277376_0001
# 2024-01-08 16:09:00,797 INFO mapreduce.JobSubmitter: Executing with tokens: []
# 2024-01-08 16:09:01,489 INFO mapred.LocalDistributedCacheManager: Localized file:/content/A1Ej2Map.py as file:/tmp/hadoop-root/mapred/local/job_local280277376_0001_19210f34-0b27-4294-b17c-531dd00f0075/A1Ej2Map.py
# ...

# %%
# !head ./salida2/*
# Out:
# ==> ./salida2/part-00000 <==
# 1	3964859,4647229
# 10000	4539112
# 100000	5031388
# 1000006	4714284
# 1000007	4766693
# 1000011	5033339
# 1000017	3908629
# 1000026	4043055
# 1000033	4190903,4975983
# 1000043	4091523
#
# ==> ./salida2/_SUCCESS <==
